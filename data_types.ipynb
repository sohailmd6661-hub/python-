# %% [markdown]
# **Python Data types**
#
# `we have 3 data types in python `
#
#        - `Integer -> int -> ex: (whole numbers -> 12 | 156 | 2860 ) etc... `
#        - `float -> float -> ex: (decimals -> 12.5 | 156.0 | 2860.66) etc...`
#        - `string -> str -> ex : (anything in between the ' <> ' -> 'kumar' | 'kumar12' | '125')`

# %%
12 #int
# Out:
# 12

# %%
7.98 #float
# Out:
# 7.98

# %%
'sohail'
# Out:
# 'sohail'
